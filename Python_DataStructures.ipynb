# %% [markdown]
# ---
#
# Load essential libraries
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('dark_background')
# %matplotlib inline
import sys

# %% [markdown]
# ---
#
# Mount Google Drive folder if running Google Colab
#
# ---

# %%
## Mount Google drive folder if running in Colab
if('google.colab' in sys.modules):
    from google.colab import drive
    drive.mount('/content/drive', force_remount = True)
    DIR = '/content/drive/MyDrive/Colab Notebooks/MAHE/MSIS Coursework/OddSem2025MAHE'
    DATA_DIR = DIR+'/Data/'
else:
    DATA_DIR = 'Data/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
# Load the food texture dataset into a dataframe
#
# ---

# %%
## Load the food texture dataset
FILE = ?
df_food = ?
df_food.head(5)

# %% [markdown]
# ---
#
# Data structures in Python: (1) *list* (2) *dictionary* (3) *numpy array* (4) *tuple*.
#
# A data structure that is not discussed here is the *set*.
#
# ---

# %% [markdown]
# ---
#
# A list example
#
# ---

# %% [markdown]
# ---
#
# Pandas series
#
# ---

# %% [markdown]
# ---
#
# Dictionary
#
# ---

# %% [markdown]
# ---
#
# Numpy array
#
# ---

# %% [markdown]
# ---
#
# Dataframes
#
# ---

# %% [markdown]
# ---
#
# Plotting in Python
#
# ---

# %%
# Visualize the relationship between 2 continuous features: Oil and Density
# A scatter plot relates 2 continuous features

# %%
# Visualize a single continuous feature: Oil
# Histogram

# %% [markdown]
# ---
#
# List comprehension
#
# ---

# %%
# One way to create the list of Crispylevel values


# A compact way to create the list of Crispylevel values using
# list comprehension

# %% [markdown]
# ---
#
# apply() method for dataframes
#
# ---

# %%
# Create a new column called Crispylevel with values
# 'High' (Crispy > 11) and 'Low' (Crispy <= 11)

# %%
# Create list of categorical and continuous features
categorical_features = ?
continuous_features = ?

# %%
# Assign the 'category' datatype to the categorical columns
?

# %%
# Scatter plot between Oil and Density color-coded using Crispylevel
fig, ax = plt.subplots(1, figsize = (3, 3)) # creates a figure and axis object
ax.scatter(?)
ax.set_xlabel('Oil Percentage', fontsize = 10)
ax.set_ylabel('Density (Kg/m^3)', fontsize = 10)
ax.set_title('Density vs. Oil Percentage', fontsize = 11);

# %%
# Visualizing the relationship between a continuous and a
# categorical feature using a box-plot
# Box-plot between Oil and Crispylevel
fig, ax = plt.subplots(1, figsize = (3, 3)) # creates a figure and axis object
?
